# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import requests
import numpy as np

# %%
# API ULRS

# L'URL de l'API pour donné de compteur
limit_datacount = 40

base_datacount_url = f"https://data.metropole-rouen-normandie.fr/api/explore/v2.1/catalog/datasets/eco-counter-data/records"
base_counter_location_url = f"https://data.metropole-rouen-normandie.fr/api/explore/v2.1/catalog/datasets/eco-counter-sites/records"

datacount_url = f"https://data.metropole-rouen-normandie.fr/api/explore/v2.1/catalog/datasets/eco-counter-data/records?limit={str(limit_datacount)}"
counter_location_url = f"https://data.metropole-rouen-normandie.fr/api/explore/v2.1/catalog/datasets/eco-counter-sites/records?limit={str(limit_datacount)}"

# %%
# Effectuer une requête GET pour obtenir les données
response_datacount = requests.get(datacount_url)
response_localisation = requests.get(counter_location_url)

if (response_datacount.status_code != 200):
    print(f'Échec de la requête HTTP, code de statut {response_datacount.status_code}')

if (response_localisation.status_code != 200):
    print(f'Échec de la requête HTTP, code de statut {response_localisation.status_code}')

    


# Si la requête a réussi (code de statut HTTP 200), vous pouvez accéder aux données
data_datacount = response_datacount.json()  # Convertit la réponse JSON en un objet Python
data_localisation = response_localisation.json()

total_count = data_datacount['total_count']
results_datacount = data_datacount['results']
results_localisation = data_localisation['results']

# %%
data_datacount
# Out:
# {'total_count': 348084,
#  'results': [{'id': '100007116',
#    'date': '2022-04-04T01:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-04'},
#   {'id': '100007116',
#    'date': '2022-04-04T03:00:00+00:00',
#    'counts': 1,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-04'},
#   {'id': '100007116',
#    'date': '2022-04-04T04:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-04'},
#   {'id': '100007116',
#    'date': '2022-04-04T10:00:00+00:00',
#    'counts': 5,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-04'},
#   {'id': '100007116',
#    'date': '2022-04-04T14:00:00+00:00',
#    'counts': 4,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-04'},
#   {'id': '100007116',
#    'date': '2022-04-04T19:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-04'},
#   {'id': '100007116',
#    'date': '2022-04-06T01:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-06'},
#   {'id': '100007116',
#    'date': '2022-04-06T04:00:00+00:00',
#    'counts': 3,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-06'},
#   {'id': '100007116',
#    'date': '2022-04-06T09:00:00+00:00',
#    'counts': 5,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-06'},
#   {'id': '100007116',
#    'date': '2022-04-06T14:00:00+00:00',
#    'counts': 6,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-06'},
#   {'id': '100007116',
#    'date': '2022-04-06T23:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-07'},
#   {'id': '100007116',
#    'date': '2022-04-07T02:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-07'},
#   {'id': '100007116',
#    'date': '2022-04-07T05:00:00+00:00',
#    'counts': 4,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-07'},
#   {'id': '100007116',
#    'date': '2022-04-07T08:00:00+00:00',
#    'counts': 3,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-07'},
#   {'id': '100007116',
#    'date': '2022-04-07T14:00:00+00:00',
#    'counts': 7,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-07'},
#   {'id': '100007116',
#    'date': '2022-04-07T21:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-07'},
#   {'id': '100007116',
#    'date': '2022-04-08T08:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-08'},
#   {'id': '100007116',
#    'date': '2022-04-08T12:00:00+00:00',
#    'counts': 2,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-08'},
#   {'id': '100007116',
#    'date': '2022-04-09T02:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T04:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T11:00:00+00:00',
#    'counts': 5,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T12:00:00+00:00',
#    'counts': 5,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T13:00:00+00:00',
#    'counts': 5,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T16:00:00+00:00',
#    'counts': 4,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T18:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-09T21:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-09'},
#   {'id': '100007116',
#    'date': '2022-04-10T00:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T05:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T06:00:00+00:00',
#    'counts': 1,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T07:00:00+00:00',
#    'counts': 3,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T12:00:00+00:00',
#    'counts': 14,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T14:00:00+00:00',
#    'counts': 22,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T16:00:00+00:00',
#    'counts': 4,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T17:00:00+00:00',
#    'counts': 5,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T19:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T20:00:00+00:00',
#    'counts': 4,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T21:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-10'},
#   {'id': '100007116',
#    'date': '2022-04-10T22:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-11'},
#   {'id': '100007116',
#    'date': '2022-04-11T03:00:00+00:00',
#    'counts': 0,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-11'},
#   {'id': '100007116',
#    'date': '2022-04-11T05:00:00+00:00',
#    'counts': 7,
#    'status': 'raw',
#    'name': "Eco 08 - Avenue de l'Europe MONT ST AIGNAN",
#    'user_type': 'Vélo',
#    'photourl': 'https://filer.eco-counter-tools.com/file/7d/83351f3d0923ac2b2412cb3fab54e4318aac15433ddf945382bf672a62ac1c7d/13594522270460.jpg',
#    'date_j': '2022-04-11'}]}

# %%
count_data = pd.DataFrame(results_datacount)
count_data
# Out:
#            id                       date  counts status
# 0   100007116  2022-04-04T01:00:00+00:00       0    raw  \
# 1   100007116  2022-04-04T03:00:00+00:00       1    raw
# 2   100007116  2022-04-04T04:00:00+00:00       0    raw
# 3   100007116  2022-04-04T10:00:00+00:00       5    raw
# 4   100007116  2022-04-04T14:00:00+00:00       4    raw
# 5   100007116  2022-04-04T19:00:00+00:00       0    raw
# 6   100007116  2022-04-06T01:00:00+00:00       0    raw
# 7   100007116  2022-04-06T04:00:00+00:00       3    raw
# 8   100007116  2022-04-06T09:00:00+00:00       5    raw
# 9   100007116  2022-04-06T14:00:00+00:00       6    raw
# 10  100007116  2022-04-06T23:00:00+00:00       0    raw
# 11  100007116  2022-04-07T02:00:00+00:00       0    raw
# 12  100007116  2022-04-07T05:00:00+00:00       4    raw
# 13  100007116  2022-04-07T08:00:00+00:00       3    raw
# 14  100007116  2022-04-07T14:00:00+00:00       7    raw
# 15  100007116  2022-04-07T21:00:00+00:00       0    raw
# 16  100007116  2022-04-08T08:00:00+00:00       0    raw
# 17  100007116  2022-04-08T12:00:00+00:00       2    raw
# 18  100007116  2022-04-09T02:00:00+00:00       0    raw
# 19  100007116  2022-04-09T04:00:00+00:00       0    raw
# 20  100007116  2022-04-09T11:00:00+00:00       5    raw
# 21  100007116  2022-04-09T12:00:00+00:00       5    raw
# 22  100007116  2022-04-09T13:00:00+00:00       5    raw
# 23  100007116  2022-04-09T16:00:00+00:00       4    raw
# 24  100007116  2022-04-09T18:00:00+00:00       0    raw
# 25  100007116  2022-04-09T21:00:00+00:00       0    raw
# 26  100007116  2022-04-10T00:00:00+00:00       0    raw
# 27  100007116  2022-04-10T05:00:00+00:00       0    raw
# 28  100007116  2022-04-10T06:00:00+00:00       1    raw
# 29  100007116  2022-04-10T07:00:00+00:00       3    raw
# 30  100007116  2022-04-10T12:00:00+00:00      14    raw
# 31  100007116  2022-04-10T14:00:00+00:00      22    raw
# 32  100007116  2022-04-10T16:00:00+00:00       4    raw
# 33  100007116  2022-04-10T17:00:00+00:00       5    raw
# 34  100007116  2022-04-10T19:00:00+00:00       0    raw
# 35  100007116  2022-04-10T20:00:00+00:00       4    raw
# 36  100007116  2022-04-10T21:00:00+00:00       0    raw
# 37  100007116  2022-04-10T22:00:00+00:00       0    raw
# 38  100007116  2022-04-11T03:00:00+00:00       0    raw
# 39  100007116  2022-04-11T05:00:00+00:00       7    raw
#
#                                           name user_type
# 0   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo  \
# 1   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 2   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 3   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 4   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 5   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 6   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 7   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 8   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 9   Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 10  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 11  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 12  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 13  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 14  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 15  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 16  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 17  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 18  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 19  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 20  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 21  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 22  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 23  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 24  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 25  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 26  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 27  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 28  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 29  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 30  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 31  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 32  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 33  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 34  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 35  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 36  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 37  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 38  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 39  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
#
#                                              photourl      date_j
# 0   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 1   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 2   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 3   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 4   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 5   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 6   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-06
# 7   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-06
# 8   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-06
# 9   https://filer.eco-counter-tools.com/file/7d/83...  2022-04-06
# 10  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-07
# 11  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-07
# 12  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-07
# 13  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-07
# 14  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-07
# 15  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-07
# 16  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-08
# 17  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-08
# 18  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 19  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 20  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 21  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 22  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 23  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 24  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 25  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-09
# 26  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 27  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 28  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 29  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 30  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 31  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 32  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 33  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 34  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 35  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 36  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-10
# 37  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-11
# 38  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-11
# 39  https://filer.eco-counter-tools.com/file/7d/83...  2022-04-11

# %%
location_data = pd.DataFrame(results_localisation)
location_data
# Out:
#            id                                          name user_type
# 0   100007115   Eco 07 - Sente des Forrieres BOIS GUILLAUME      Vélo  \
# 1   100007117  Eco 09 - Avenue des Canadiens GRAND QUEVILLY      Vélo
# 2   100018293      Eco 11 - Rue Petites Eaux du Robec ROUEN      Vélo
# 3   100033300          Eco 16 - Quai Pierre Corneille ROUEN      Vélo
# 4   100048215         Eco 18 - Avenue Jacques Cartier ROUEN      Vélo
# 5   300028856                 Eco 21 - Rue Grand Pont ROUEN      Vélo
# 6   300033641              Eco 23 - Pont Jeanne d'Arc ROUEN      Vélo
# 7   300033642                 Eco 24 - Pont Corneille ROUEN      Vélo
# 8   300035455               Eco 27 - Blvd de l'Europe ROUEN      Vélo
# 9   100005527          Eco 02 - Chemin du Halage SOTTEVILLE      Vélo
# 10  100019265                Eco 04 - Zénith GRAND QUEVILLY      Vélo
# 11  100033301              Eco 15 - Chemin du Halage ELBEUF      Vélo
# 12  100037866             Eco 17 - Boulevard Gambetta ROUEN      Vélo
# 13  100057696                 Eco 03 - Pont Boieldieu ROUEN      Vélo
# 14  100057697            Eco 10 - Pont Guillaume Nord ROUEN      Vélo
# 15  300033014            Eco 22 - Rte de Paris FRANQUEVILLE      Vélo
# 16  300037150                  Eco 00 - Quai du Havre ROUEN      Vélo
# 17  100005524        Eco 05 - Rue Boucicault MONT ST AIGNAN      Vélo
# 18  100005525  Eco 06 - Rue de la Prevotiere BOIS GUILLAUME      Vélo
# 19  100007116    Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 20  100018089                Eco 19 - Bords de Seine SAHURS      Vélo
# 21  100018294       Eco 12 - Rue de la Foret VAL DE LA HAYE      Vélo
# 22  100033302        Eco 14 - Quai Pre Aux Loups AMFREVILLE      Vélo
# 23  100056983           Eco 01 - Avenue Jean Rondeaux ROUEN      Vélo
# 24  300023463        Eco 13 - Route de Lyons La Forêt ROUEN      Vélo
# 25  300027449            Eco 20 - Rue Clarin Mustad DUCLAIR      Vélo
# 26  300035379                   Eco 25 - Rue d'Elbeuf ROUEN      Vélo
# 27  300035391                 Eco 26 - Avenue Pasteur ROUEN      Vélo
#
#                       commune                          coordinates  interval
# 0              Bois-Guillaume    {'lon': 1.12455, 'lat': 49.48484}        60  \
# 1    Saint-Étienne-du-Rouvray    {'lon': 1.06419, 'lat': 49.40027}        60
# 2                       Rouen    {'lon': 1.12737, 'lat': 49.43898}        60
# 3                       Rouen  {'lon': 1.094459, 'lat': 49.437748}        60
# 4                       Rouen     {'lon': 1.0868, 'lat': 49.43589}        60
# 5                       Rouen  {'lon': 1.092819, 'lat': 49.439597}        15
# 6                       Rouen   {'lon': 1.08807, 'lat': 49.437928}        15
# 7                       Rouen  {'lon': 1.095028, 'lat': 49.435649}        15
# 8                       Rouen  {'lon': 1.094733, 'lat': 49.428725}        15
# 9        Sotteville-lès-Rouen     {'lon': 1.11105, 'lat': 49.4155}        60
# 10             Petit-Couronne    {'lon': 1.05432, 'lat': 49.38941}        60
# 11        Caudebec-lès-Elbeuf    {'lon': 1.02963, 'lat': 49.29275}        60
# 12                      Rouen    {'lon': 1.08807, 'lat': 49.43931}        60
# 13                      Rouen     {'lon': 1.09039, 'lat': 49.4362}        60
# 14                      Rouen    {'lon': 1.08224, 'lat': 49.44168}        60
# 15  Franqueville-Saint-Pierre  {'lon': 1.184115, 'lat': 49.395449}        15
# 16                      Rouen  {'lon': 1.088072, 'lat': 49.439309}        60
# 17          Mont-Saint-Aignan    {'lon': 1.08164, 'lat': 49.47629}        60
# 18                    Bihorel    {'lon': 1.12962, 'lat': 49.46501}        60
# 19          Mont-Saint-Aignan    {'lon': 1.10022, 'lat': 49.47727}        60
# 20                     Sahurs  {'lon': 0.932053, 'lat': 49.354957}        60
# 21             Val-de-la-Haye     {'lon': 1.0044, 'lat': 49.37838}        60
# 22                      Rouen    {'lon': 1.11013, 'lat': 49.42832}        60
# 23                      Rouen    {'lon': 1.07981, 'lat': 49.43843}        60
# 24                      Rouen   {'lon': 1.13399, 'lat': 49.436331}        15
# 25                    Duclair  {'lon': 0.868815, 'lat': 49.479322}        60
# 26                      Rouen   {'lon': 1.083794, 'lat': 49.42699}        15
# 27                      Rouen  {'lon': 1.078119, 'lat': 49.443063}        60
#
#         counter                                           photourl
# 0   X2H21080481  https://filer.eco-counter-tools.com/file/d4/f7...
# 1   X2I22032462  https://filer.eco-counter-tools.com/file/31/3d...
# 2   X2H22042904  https://filer.eco-counter-tools.com/file/7c/3f...
# 3   XTH17052118  https://filer.eco-counter-tools.com/file/9d/b9...
# 4   X2H21070194  https://filer.eco-counter-tools.com/file/b8/26...
# 5   CAI0DECC2A1  https://filer.eco-counter-tools.com/file/70/29...
# 6   RAD0003CE2E  https://filer.eco-counter-tools.com/file/0e/da...
# 7   RAD0003CE2F  https://filer.eco-counter-tools.com/file/67/18...
# 8   COM23060707  https://filer.eco-counter-tools.com/file/34/02...
# 9   X2H22084005  https://filer.eco-counter-tools.com/file/a4/a2...
# 10  X2H19070425  https://filer.eco-counter-tools.com/file/f1/c9...
# 11  X2H22073825  https://filer.eco-counter-tools.com/file/59/a1...
# 12         None  https://filer.eco-counter-tools.com/file/b5/15...
# 13  X2I19121627  https://filer.eco-counter-tools.com/file/e3/47...
# 14  X2I19121628  https://filer.eco-counter-tools.com/file/e9/1a...
# 15  RAD0003CE34  https://filer.eco-counter-tools.com/file/f6/3a...
# 16  X2I21111002  https://filer.eco-counter-tools.com/file/3f/78...
# 17  X2H22042725  https://filer.eco-counter-tools.com/file/88/1d...
# 18  X2H22042724  https://filer.eco-counter-tools.com/file/3f/51...
# 19  X2H21080482  https://filer.eco-counter-tools.com/file/7d/83...
# 20  X2H22042726  https://filer.eco-counter-tools.com/file/05/44...
# 21  X2I22104658  https://filer.eco-counter-tools.com/file/da/73...
# 22  X2I22032461  https://filer.eco-counter-tools.com/file/80/da...
# 23  X2I19111447  https://filer.eco-counter-tools.com/file/3e/39...
# 24  COM22040600  https://filer.eco-counter-tools.com/file/b8/23...
# 25  X2H22084028  https://filer.eco-counter-tools.com/file/a2/5f...
# 26  ZLT23070260  https://filer.eco-counter-tools.com/file/1b/a4...
# 27  X2I20104344  https://filer.eco-counter-tools.com/file/cf/c3...

# %%
def get_count_data_as_dataframe(
        limit : int = 50, 
        offset : int = 0, 
        select : str = "", 
        where  : str  = "",
        group_by : str = "",
        order_by : str = "",
        refine : dict = {},
        exclude : dict = {}
        )  -> pd.DataFrame:
    

    # query = f"?limit={limit}" \
    #         f"&offset={offset}" \
    
    if select != "":
        query += f"&select={select}" 
    
    if where != "":
        query += f"&where={where}" 

    if group_by != "":
        query += f"&group_by={group_by}" 

    if order_by != "":
        query += f"&order_by={order_by}" 

    if refine != {}:
        for key in refine:
            query += f"&refine={key}%3A{refine[key]}"

    if exclude != {}:
        for key in exclude:
            query += f"&exclude={key}%3A{exclude[key]}"
        
    if limit <= 100:
        query = f"?limit={limit}" \
            f"&offset={offset}" 
        response = requests.get(base_datacount_url + query).json()
        total_count = response["total_count"] 
        data = response["results"]

    else:
        # le nombre de requete de limité à 100 entrés possible
        nbre_request = limit // 100
        # le nombre d'entré de la derniere requete
        last_limit = limit  % 100
        data = []
        for idx_req in range(nbre_request):
            query = f"?limit={100}" \
                    f"&offset={offset + idx_req*100}"
            response = requests.get(base_datacount_url + query).json() 
            data += response["results"]
        query = f"?limit={last_limit}" \
                f"&offset={offset + (idx_req + 1)*100}"
        response = requests.get(base_datacount_url + query).json() 
        data += response["results"]
        total_count = response["total_count"] 
    return total_count, pd.DataFrame(data)

# %%
_,df = get_count_data_as_dataframe(limit=226)
df
# Out:
#             id                       date  counts status
# 0    100007116  2022-04-04T01:00:00+00:00       0    raw  \
# 1    100007116  2022-04-04T03:00:00+00:00       1    raw
# 2    100007116  2022-04-04T04:00:00+00:00       0    raw
# 3    100007116  2022-04-04T10:00:00+00:00       5    raw
# 4    100007116  2022-04-04T14:00:00+00:00       4    raw
# ..         ...                        ...     ...    ...
# 221  100007116  2022-05-02T15:00:00+00:00      18    raw
# 222  100007116  2022-05-03T08:00:00+00:00       4    raw
# 223  100007116  2022-05-03T09:00:00+00:00       5    raw
# 224  100007116  2022-05-03T11:00:00+00:00       6    raw
# 225  100007116  2022-05-03T13:00:00+00:00       8    raw
#
#                                            name user_type
# 0    Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo  \
# 1    Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 2    Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 3    Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 4    Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# ..                                          ...       ...
# 221  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 222  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 223  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 224  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
# 225  Eco 08 - Avenue de l'Europe MONT ST AIGNAN      Vélo
#
#                                               photourl      date_j
# 0    https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 1    https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 2    https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 3    https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# 4    https://filer.eco-counter-tools.com/file/7d/83...  2022-04-04
# ..                                                 ...         ...
# 221  https://filer.eco-counter-tools.com/file/7d/83...  2022-05-02
# 222  https://filer.eco-counter-tools.com/file/7d/83...  2022-05-03
# 223  https://filer.eco-counter-tools.com/file/7d/83...  2022-05-03
# 224  https://filer.eco-counter-tools.com/file/7d/83...  2022-05-03
# 225  https://filer.eco-counter-tools.com/file/7d/83...  2022-05-03
#
# [226 rows x 8 columns]
