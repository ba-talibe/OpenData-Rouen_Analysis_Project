# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from environs import Env
import seaborn as sns
from data_toolset.data_loading import load_dataset

# %%
env = Env()
env.read_env(".env")
# Out:
# True

# %%
import plotly.express as px
import ipywidgets as ipw

# %% [markdown]
# # chargement des données

# %%
import os
dataset_path = os.path.join(os.getcwd(), env('dataset_folder'))
df = load_dataset(dataset_path)
#df["date"] = pd.to_datetime(df["date"])
print(df.index)
df
# Out:
# 1344
# Index([2024-02-02 23:00:00+01:00, 2024-02-02 23:00:00+01:00,
#        2024-02-02 23:00:00+01:00, 2024-02-02 23:00:00+01:00,
#        2024-02-02 23:00:00+01:00, 2024-02-02 23:00:00+01:00,
#        2024-02-02 23:00:00+01:00, 2024-02-02 23:00:00+01:00,
#        2024-02-02 23:00:00+01:00, 2024-02-02 23:00:00+01:00,
#        ...
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00],
#       dtype='object', name='date', length=385940)
#                                   id  counts status  \
# date
# 2024-02-02 23:00:00+01:00  300028856      15    raw
# 2024-02-02 23:00:00+01:00  300035391       8    raw
# 2024-02-02 23:00:00+01:00  300023463       1    raw
# 2024-02-02 23:00:00+01:00  300037150       7    raw
# 2024-02-02 23:00:00+01:00  100018089       0    raw
# ...                              ...     ...    ...
# 2022-01-01 00:00:00+01:00  100033300       8    raw
# 2022-01-01 00:00:00+01:00  100048215       2    raw
# 2022-01-01 00:00:00+01:00  100019265       0    raw
# 2022-01-01 00:00:00+01:00  100007115       0    raw
# 2022-01-01 00:00:00+01:00  100005525       0    raw
#
#                                                                    name  \
# date
# 2024-02-02 23:00:00+01:00            Eco 21 - Rue General Leclerc ROUEN
# 2024-02-02 23:00:00+01:00                 Eco 26 - Avenue Pasteur ROUEN
# 2024-02-02 23:00:00+01:00        Eco 13 - Route de Lyons La Forêt ROUEN
# 2024-02-02 23:00:00+01:00                  Eco 00 - Quai du Havre ROUEN
# 2024-02-02 23:00:00+01:00                Eco 19 - Bords de Seine SAHURS
# ...                                                                 ...
# 2022-01-01 00:00:00+01:00          Eco 16 - Quai Pierre Corneille ROUEN
# 2022-01-01 00:00:00+01:00         Eco 18 - Avenue Jacques Cartier ROUEN
# 2022-01-01 00:00:00+01:00                Eco 04 - Zénith GRAND QUEVILLY
# 2022-01-01 00:00:00+01:00   Eco 07 - Sente des Forrieres BOIS GUILLAUME
# 2022-01-01 00:00:00+01:00  Eco 06 - Rue de la Prevotiere BOIS GUILLAUME
#
#                           user_type  \
# date
# 2024-02-02 23:00:00+01:00      Vélo
# 2024-02-02 23:00:00+01:00      Vélo
# 2024-02-02 23:00:00+01:00      Vélo
# 2024-02-02 23:00:00+01:00      Vélo
# 2024-02-02 23:00:00+01:00      Vélo
# ...                             ...
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
#
#                                                                     photourl  \
# date
# 2024-02-02 23:00:00+01:00  https://filer.eco-counter-tools.com/file/70/29...
# 2024-02-02 23:00:00+01:00  https://filer.eco-counter-tools.com/file/cf/c3...
# 2024-02-02 23:00:00+01:00  https://filer.eco-counter-tools.com/file/b8/23...
# 2024-02-02 23:00:00+01:00  https://filer.eco-counter-tools.com/file/3f/78...
# 2024-02-02 23:00:00+01:00  https://filer.eco-counter-tools.com/file/05/44...
# ...                                                                      ...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/9d/b9...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/b8/26...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/f1/c9...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/d4/f7...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/3f/51...
#
#                                date_j
# date
# 2024-02-02 23:00:00+01:00  2024-02-02
# 2024-02-02 23:00:00+01:00  2024-02-02
# 2024-02-02 23:00:00+01:00  2024-02-02
# 2024-02-02 23:00:00+01:00  2024-02-02
# 2024-02-02 23:00:00+01:00  2024-02-02
# ...                               ...
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
#
# [385940 rows x 7 columns]

# %%
df.loc[pd.to_datetime("2024-01-01 00:00:00+01:00", utc=True): pd.to_datetime('2024-01-27 23:00:00+01:00', utc=True)]
# Out:
# Empty DataFrame
# Columns: [id, counts, status, name, user_type, photourl, date_j]
# Index: []

# %%
tidf = df.copy() # time indexed dataframe
tidf.index = pd.to_datetime(tidf.index, utc=True)
tidf.index
# Out:
# DatetimeIndex(['2024-02-02 22:00:00+00:00', '2024-02-02 22:00:00+00:00',
#                '2024-02-02 22:00:00+00:00', '2024-02-02 22:00:00+00:00',
#                '2024-02-02 22:00:00+00:00', '2024-02-02 22:00:00+00:00',
#                '2024-02-02 22:00:00+00:00', '2024-02-02 22:00:00+00:00',
#                '2024-02-02 22:00:00+00:00', '2024-02-02 22:00:00+00:00',
#                ...
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='date', length=385940, freq=None)

# %% [markdown]
# ## donnée des compteurs par jours

# %%
daily_counts_per_counter = tidf[["counts"]].groupby([pd.Grouper(freq="h")]).sum()
daily_counts_per_counter.plot(figsize=(17, 8))
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## Données des comptage par heures

# %%
counts_per_hour = tidf[["counts"]].groupby([pd.Grouper(freq="h")]).sum()
counts_per_hour
# Out:
#                            counts
# date
# 2021-12-31 23:00:00+00:00      27
# 2022-01-01 00:00:00+00:00      25
# 2022-01-01 01:00:00+00:00      12
# 2022-01-01 02:00:00+00:00      23
# 2022-01-01 03:00:00+00:00      15
# ...                           ...
# 2024-02-02 18:00:00+00:00     767
# 2024-02-02 19:00:00+00:00     499
# 2024-02-02 20:00:00+00:00     305
# 2024-02-02 21:00:00+00:00     263
# 2024-02-02 22:00:00+00:00     241
#
# [18312 rows x 1 columns]

# %%
counts_per_hour["date"] = counts_per_hour.index
counts_per_hour["day_name"] = counts_per_hour.date.dt.day_name()
counts_per_hour["hours"] = counts_per_hour.date.dt.hour
counts_per_hour
# Out:
#                            counts                      date  day_name  hours
# date
# 2021-12-31 23:00:00+00:00      27 2021-12-31 23:00:00+00:00    Friday     23
# 2022-01-01 00:00:00+00:00      25 2022-01-01 00:00:00+00:00  Saturday      0
# 2022-01-01 01:00:00+00:00      12 2022-01-01 01:00:00+00:00  Saturday      1
# 2022-01-01 02:00:00+00:00      23 2022-01-01 02:00:00+00:00  Saturday      2
# 2022-01-01 03:00:00+00:00      15 2022-01-01 03:00:00+00:00  Saturday      3
# ...                           ...                       ...       ...    ...
# 2024-02-02 18:00:00+00:00     767 2024-02-02 18:00:00+00:00    Friday     18
# 2024-02-02 19:00:00+00:00     499 2024-02-02 19:00:00+00:00    Friday     19
# 2024-02-02 20:00:00+00:00     305 2024-02-02 20:00:00+00:00    Friday     20
# 2024-02-02 21:00:00+00:00     263 2024-02-02 21:00:00+00:00    Friday     21
# 2024-02-02 22:00:00+00:00     241 2024-02-02 22:00:00+00:00    Friday     22
#
# [18312 rows x 4 columns]

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']


counts_per_hour['day_name'] = pd.Categorical(counts_per_hour['day_name'], categories=day_order, ordered=True)




heatmap_data = counts_per_hour.pivot_table(index='hours', columns='day_name', values='counts', aggfunc='sum', fill_value=0)


plt.figure(figsize=(19, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt='d', linewidths=.5)

# Customize plot labels and title
plt.title("Comptage hoaire pour chaque jour de la semaine sur toute l'etendue des données")
plt.xlabel("heures d'une journée")
plt.ylabel("Jours de la semaine")

# Show the plot
plt.show()

# %% [markdown]
# ### Diagrammmme de chaleur de la dernier semaine

# %%
from datetime import datetime, timedelta

end_date = tidf.index[0]
start_date = end_date - timedelta(days=7)
date_range = pd.date_range(start=start_date, end=end_date, freq="H")

start_date, end_date
# Out:
# (Timestamp('2024-01-26 22:00:00+0000', tz='UTC'),
#  Timestamp('2024-02-02 22:00:00+0000', tz='UTC'))

# %%
counts_average_per_hour = tidf[["counts"]].loc[date_range].groupby([pd.Grouper(freq="h")]).mean()



counts_average_per_hour["date"] = counts_average_per_hour.index
counts_average_per_hour["day_name"] = counts_average_per_hour.date.dt.day_name()
counts_average_per_hour["hours"] = counts_average_per_hour.date.dt.hour


day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']


counts_average_per_hour['day_name'] = pd.Categorical(counts_average_per_hour['day_name'], categories=day_order, ordered=True)




heatmap_data = counts_average_per_hour.pivot_table(index='hours', columns='day_name', values='counts', aggfunc='sum', fill_value=0)


plt.figure(figsize=(19, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt=".0f", linewidths=.5)

# Customize plot labels and title
plt.title("Comptage hoaire pour chaque jour de la semaine sur toute l'etendue des données")
plt.xlabel("heures d'une journée")
plt.ylabel("Jours de la semaine")

# Show the plot
plt.show()

# %% [markdown]
# ## Diagramme de chaleur du dernier mois

# %%
from datetime import datetime, timedelta

end_date = tidf.index[0]
start_date = end_date - timedelta(days=365)
date_range = pd.date_range(start=start_date, end=end_date, freq="H")

start_date, end_date
# Out:
# (Timestamp('2023-02-02 22:00:00+0000', tz='UTC'),
#  Timestamp('2024-02-02 22:00:00+0000', tz='UTC'))

# %%
date_range
# Out:
# DatetimeIndex(['2023-02-02 22:00:00+00:00', '2023-02-02 23:00:00+00:00',
#                '2023-02-03 00:00:00+00:00', '2023-02-03 01:00:00+00:00',
#                '2023-02-03 02:00:00+00:00', '2023-02-03 03:00:00+00:00',
#                '2023-02-03 04:00:00+00:00', '2023-02-03 05:00:00+00:00',
#                '2023-02-03 06:00:00+00:00', '2023-02-03 07:00:00+00:00',
#                ...
#                '2024-02-02 13:00:00+00:00', '2024-02-02 14:00:00+00:00',
#                '2024-02-02 15:00:00+00:00', '2024-02-02 16:00:00+00:00',
#                '2024-02-02 17:00:00+00:00', '2024-02-02 18:00:00+00:00',
#                '2024-02-02 19:00:00+00:00', '2024-02-02 20:00:00+00:00',
#                '2024-02-02 21:00:00+00:00', '2024-02-02 22:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=8761, freq='H')

# %%
date_range = date_range.intersection(tidf.index)
daily_counts_average = tidf[["counts"]].loc[date_range].groupby([pd.Grouper(freq="h")]).mean()



daily_counts_average["date"] = daily_counts_average.index
daily_counts_average['month_name'] = daily_counts_average['date'].dt.strftime('%B')
daily_counts_average["hours"] = daily_counts_average.date.dt.hour


month_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 'July',
    'August', 'September', 'October', 'November', 'December'
]
daily_counts_average['month_name'] = pd.Categorical(daily_counts_average['month_name'], categories=month_order, ordered=True)




heatmap_data = daily_counts_average.pivot_table(index='hours', columns='month_name', values='counts', aggfunc='mean', fill_value=0)


plt.figure(figsize=(19, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt=".0f", linewidths=.5)

# Customize plot labels and title
plt.title("Comptage hoaire pour chaque jour de la semaine sur toute l'etendue des données")
plt.xlabel("heures d'une journée")
plt.ylabel("Jours de la semaine")

# Show the plot
plt.show()

# %% [markdown]
# ## Double indexation

# %%
didf = df.copy()
didf["date"] = didf.index
didf.set_index(["date", "id"], inplace=True)
didf
# Out:
#                                      counts status  \
# date                      id
# 2024-01-31 23:00:00+01:00 100018293       2    raw
#                           100005527       2    raw
#                           100048215       9    raw
#                           100033302       2    raw
#                           100018089       0    raw
# ...                                     ...    ...
# 2022-01-01 00:00:00+01:00 100033300       8    raw
#                           100048215       2    raw
#                           100019265       0    raw
#                           100007115       0    raw
#                           100005525       0    raw
#
#                                                                              name  \
# date                      id
# 2024-01-31 23:00:00+01:00 100018293      Eco 11 - Rue Petites Eaux du Robec ROUEN
#                           100005527          Eco 02 - Chemin du Halage SOTTEVILLE
#                           100048215         Eco 18 - Avenue Jacques Cartier ROUEN
#                           100033302        Eco 14 - Quai Pre Aux Loups AMFREVILLE
#                           100018089                Eco 19 - Bords de Seine SAHURS
# ...                                                                           ...
# 2022-01-01 00:00:00+01:00 100033300          Eco 16 - Quai Pierre Corneille ROUEN
#                           100048215         Eco 18 - Avenue Jacques Cartier ROUEN
#                           100019265                Eco 04 - Zénith GRAND QUEVILLY
#                           100007115   Eco 07 - Sente des Forrieres BOIS GUILLAUME
#                           100005525  Eco 06 - Rue de la Prevotiere BOIS GUILLAUME
#
#                                     user_type  \
# date                      id
# 2024-01-31 23:00:00+01:00 100018293      Vélo
#                           100005527      Vélo
#                           100048215      Vélo
#                           100033302      Vélo
#                           100018089      Vélo
# ...                                       ...
# 2022-01-01 00:00:00+01:00 100033300      Vélo
#                           100048215      Vélo
#                           100019265      Vélo
#                           100007115      Vélo
#                           100005525      Vélo
#
#                                                                               photourl  \
# date                      id
# 2024-01-31 23:00:00+01:00 100018293  https://filer.eco-counter-tools.com/file/7c/3f...
#                           100005527  https://filer.eco-counter-tools.com/file/a4/a2...
#                           100048215  https://filer.eco-counter-tools.com/file/b8/26...
#                           100033302  https://filer.eco-counter-tools.com/file/80/da...
#                           100018089  https://filer.eco-counter-tools.com/file/05/44...
# ...                                                                                ...
# 2022-01-01 00:00:00+01:00 100033300  https://filer.eco-counter-tools.com/file/9d/b9...
#                           100048215  https://filer.eco-counter-tools.com/file/b8/26...
#                           100019265  https://filer.eco-counter-tools.com/file/f1/c9...
#                           100007115  https://filer.eco-counter-tools.com/file/d4/f7...
#                           100005525  https://filer.eco-counter-tools.com/file/3f/51...
#
#                                          date_j
# date                      id
# 2024-01-31 23:00:00+01:00 100018293  2024-01-31
#                           100005527  2024-01-31
#                           100048215  2024-01-31
#                           100033302  2024-01-31
#                           100018089  2024-01-31
# ...                                         ...
# 2022-01-01 00:00:00+01:00 100033300  2022-01-01
#                           100048215  2022-01-01
#                           100019265  2022-01-01
#                           100007115  2022-01-01
#                           100005525  2022-01-01
#
# [384596 rows x 6 columns]
