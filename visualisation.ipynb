# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from environs import Env
import seaborn as sns
from data_toolset.data_loading import load_dataset

# %%
env = Env()
env.read_env(".env")
# Out:
# True

# %%
import plotly.express as px
import ipywidgets as ipw

# %% [markdown]
# # chargement des données

# %%
import os
dataset_path = os.path.join(os.getcwd(), env('dataset_folder'))
df = load_dataset(dataset_path)
#df["date"] = pd.to_datetime(df["date"])
print(df.index)
df
# Out:
# 0
# Index([2024-03-19 23:00:00+01:00, 2024-03-19 23:00:00+01:00,
#        2024-03-19 23:00:00+01:00, 2024-03-19 23:00:00+01:00,
#        2024-03-19 23:00:00+01:00, 2024-03-19 23:00:00+01:00,
#        2024-03-19 23:00:00+01:00, 2024-03-19 23:00:00+01:00,
#        2024-03-19 23:00:00+01:00, 2024-03-19 23:00:00+01:00,
#        ...
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00,
#        2022-01-01 00:00:00+01:00, 2022-01-01 00:00:00+01:00],
#       dtype='object', name='date', length=414171)
#                                   id  counts status  \
# date
# 2024-03-19 23:00:00+01:00  100037866       8    raw
# 2024-03-19 23:00:00+01:00  300038237       0    raw
# 2024-03-19 23:00:00+01:00  300035379       7    raw
# 2024-03-19 23:00:00+01:00  100005525       0    raw
# 2024-03-19 23:00:00+01:00  100005527       0    raw
# ...                              ...     ...    ...
# 2022-01-01 00:00:00+01:00  100033300       8    raw
# 2022-01-01 00:00:00+01:00  100048215       2    raw
# 2022-01-01 00:00:00+01:00  100019265       0    raw
# 2022-01-01 00:00:00+01:00  100007115       0    raw
# 2022-01-01 00:00:00+01:00  100005525       0    raw
#
#                                                                    name  \
# date
# 2024-03-19 23:00:00+01:00             Eco 17 - Boulevard Gambetta ROUEN
# 2024-03-19 23:00:00+01:00                   Eco 28 - Pont Jaurès ELBEUF
# 2024-03-19 23:00:00+01:00                   Eco 25 - Rue d'Elbeuf ROUEN
# 2024-03-19 23:00:00+01:00  Eco 06 - Rue de la Prevotiere BOIS GUILLAUME
# 2024-03-19 23:00:00+01:00          Eco 02 - Chemin du Halage SOTTEVILLE
# ...                                                                 ...
# 2022-01-01 00:00:00+01:00          Eco 16 - Quai Pierre Corneille ROUEN
# 2022-01-01 00:00:00+01:00         Eco 18 - Avenue Jacques Cartier ROUEN
# 2022-01-01 00:00:00+01:00                Eco 04 - Zénith GRAND QUEVILLY
# 2022-01-01 00:00:00+01:00   Eco 07 - Sente des Forrieres BOIS GUILLAUME
# 2022-01-01 00:00:00+01:00  Eco 06 - Rue de la Prevotiere BOIS GUILLAUME
#
#                           user_type  \
# date
# 2024-03-19 23:00:00+01:00      Vélo
# 2024-03-19 23:00:00+01:00      Vélo
# 2024-03-19 23:00:00+01:00      Vélo
# 2024-03-19 23:00:00+01:00      Vélo
# 2024-03-19 23:00:00+01:00      Vélo
# ...                             ...
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
# 2022-01-01 00:00:00+01:00      Vélo
#
#                                                                     photourl  \
# date
# 2024-03-19 23:00:00+01:00  https://filer.eco-counter-tools.com/file/29/90...
# 2024-03-19 23:00:00+01:00  https://filer.eco-counter-tools.com/file/19/15...
# 2024-03-19 23:00:00+01:00  https://filer.eco-counter-tools.com/file/1b/a4...
# 2024-03-19 23:00:00+01:00  https://filer.eco-counter-tools.com/file/3f/51...
# 2024-03-19 23:00:00+01:00  https://filer.eco-counter-tools.com/file/a4/a2...
# ...                                                                      ...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/9d/b9...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/b8/26...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/f1/c9...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/d4/f7...
# 2022-01-01 00:00:00+01:00  https://filer.eco-counter-tools.com/file/3f/51...
#
#                                date_j
# date
# 2024-03-19 23:00:00+01:00  2024-03-19
# 2024-03-19 23:00:00+01:00  2024-03-19
# 2024-03-19 23:00:00+01:00  2024-03-19
# 2024-03-19 23:00:00+01:00  2024-03-19
# 2024-03-19 23:00:00+01:00  2024-03-19
# ...                               ...
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
# 2022-01-01 00:00:00+01:00  2022-01-01
#
# [414171 rows x 7 columns]

# %%
tidf = df.copy() # time indexed dataframe
tidf.index = pd.to_datetime(tidf.index, utc=True)
tidf.index
# Out:
# DatetimeIndex(['2024-03-19 22:00:00+00:00', '2024-03-19 22:00:00+00:00',
#                '2024-03-19 22:00:00+00:00', '2024-03-19 22:00:00+00:00',
#                '2024-03-19 22:00:00+00:00', '2024-03-19 22:00:00+00:00',
#                '2024-03-19 22:00:00+00:00', '2024-03-19 22:00:00+00:00',
#                '2024-03-19 22:00:00+00:00', '2024-03-19 22:00:00+00:00',
#                ...
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00',
#                '2021-12-31 23:00:00+00:00', '2021-12-31 23:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='date', length=414171, freq=None)

# %% [markdown]
# ## Donnée des compteurs par jours

# %% [markdown]
# # Visualisation des données

# %% [markdown]
# ## Carte des chaleurs

# %%
daily_counts_per_counter = tidf[["counts"]].groupby([pd.Grouper(freq="h")]).sum()
daily_counts_per_counter.plot(figsize=(17, 8))
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Données des comptage par heures

# %%
counts_per_hour = tidf[["counts"]].groupby([pd.Grouper(freq="h")]).mean()
counts_per_hour
# Out:
#                               counts
# date
# 2021-12-31 23:00:00+00:00   1.687500
# 2022-01-01 00:00:00+00:00   1.562500
# 2022-01-01 01:00:00+00:00   0.750000
# 2022-01-01 02:00:00+00:00   1.437500
# 2022-01-01 03:00:00+00:00   0.937500
# ...                              ...
# 2024-03-19 18:00:00+00:00  36.517241
# 2024-03-19 19:00:00+00:00  23.413793
# 2024-03-19 20:00:00+00:00  12.827586
# 2024-03-19 21:00:00+00:00  11.068966
# 2024-03-19 22:00:00+00:00   5.137931
#
# [19416 rows x 1 columns]

# %%
counts_per_hour["date"] = counts_per_hour.index
counts_per_hour["day_name"] = counts_per_hour.date.dt.day_name()
counts_per_hour["hours"] = counts_per_hour.date.dt.hour
counts_per_hour
# Out:
#                               counts                      date  day_name  \
# date
# 2021-12-31 23:00:00+00:00   1.687500 2021-12-31 23:00:00+00:00    Friday
# 2022-01-01 00:00:00+00:00   1.562500 2022-01-01 00:00:00+00:00  Saturday
# 2022-01-01 01:00:00+00:00   0.750000 2022-01-01 01:00:00+00:00  Saturday
# 2022-01-01 02:00:00+00:00   1.437500 2022-01-01 02:00:00+00:00  Saturday
# 2022-01-01 03:00:00+00:00   0.937500 2022-01-01 03:00:00+00:00  Saturday
# ...                              ...                       ...       ...
# 2024-03-19 18:00:00+00:00  36.517241 2024-03-19 18:00:00+00:00   Tuesday
# 2024-03-19 19:00:00+00:00  23.413793 2024-03-19 19:00:00+00:00   Tuesday
# 2024-03-19 20:00:00+00:00  12.827586 2024-03-19 20:00:00+00:00   Tuesday
# 2024-03-19 21:00:00+00:00  11.068966 2024-03-19 21:00:00+00:00   Tuesday
# 2024-03-19 22:00:00+00:00   5.137931 2024-03-19 22:00:00+00:00   Tuesday
#
#                            hours
# date
# 2021-12-31 23:00:00+00:00     23
# 2022-01-01 00:00:00+00:00      0
# 2022-01-01 01:00:00+00:00      1
# 2022-01-01 02:00:00+00:00      2
# 2022-01-01 03:00:00+00:00      3
# ...                          ...
# 2024-03-19 18:00:00+00:00     18
# 2024-03-19 19:00:00+00:00     19
# 2024-03-19 20:00:00+00:00     20
# 2024-03-19 21:00:00+00:00     21
# 2024-03-19 22:00:00+00:00     22
#
# [19416 rows x 4 columns]

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']


counts_per_hour['day_name'] = pd.Categorical(counts_per_hour['day_name'], categories=day_order, ordered=True)




heatmap_data = counts_per_hour.pivot_table(index='hours', columns='day_name', values='counts', aggfunc='mean', fill_value=0)
heatmap_data
# Out:
# day_name     Monday    Tuesday  Wednesday   Thursday     Friday   Saturday  \
# hours
# 0          0.620757   0.525177   0.735302   0.783136   1.055176   1.644017
# 1          0.537345   0.452719   0.570492   0.574592   0.784099   1.148784
# 2          0.840385   0.855049   0.896412   0.902683   0.994359   1.025541
# 3          1.510535   1.719645   1.815966   1.694562   1.801444   1.243874
# 4          3.094187   3.558313   3.436873   3.368253   3.207533   1.588300
# 5         11.251204  13.484786  12.745503  12.295639  10.808439   2.439514
# 6         27.628671  32.460963  28.085755  29.183081  24.966145   5.114292
# 7         26.143408  29.462179  25.225434  26.998793  23.588175   9.485782
# 8         14.862115  17.115840  16.414202  16.383047  15.404377  13.806058
# 9         13.620948  15.116846  15.217587  14.958863  14.595686  16.601294
# 10        17.306605  19.298964  19.860901  18.971241  19.081110  17.594589
# 11        19.627540  21.575946  22.113109  21.258719  20.901851  16.230851
# 12        18.700713  20.400896  21.170898  19.755886  19.897712  17.304632
# 13        17.815496  18.836588  20.435075  18.710539  19.101247  19.424549
# 14        22.027295  23.717890  24.363198  22.699255  23.887950  20.424784
# 15        32.066565  34.951961  33.308579  32.681697  30.503296  20.864970
# 16        35.779809  38.949911  36.460508  35.971297  30.401046  19.215335
# 17        27.497007  30.227308  28.389247  28.729333  24.394061  16.467542
# 18        17.737516  19.856046  19.209396  19.582054  18.116109  13.606928
# 19        11.646320  12.541121  12.503880  12.473832  12.589844  10.261524
# 20         7.048746   8.597781   8.471683   8.861650   8.994817   7.315687
# 21         4.371949   5.804786   5.668732   6.140728   6.618989   5.567576
# 22         2.300355   3.072828   3.129993   3.611987   4.605021   4.052148
# 23         1.190364   1.631584   1.592699   2.023926   2.861870   2.763407
#
# day_name     Sunday
# hours
# 0          1.667780
# 1          1.216811
# 2          0.841967
# 3          0.856460
# 4          1.169773
# 5          1.733226
# 6          3.894906
# 7          8.201431
# 8         14.138623
# 9         18.935295
# 10        18.827717
# 11        15.082070
# 12        15.683003
# 13        19.101166
# 14        21.136386
# 15        20.918482
# 16        18.734779
# 17        14.999916
# 18        11.900066
# 19         9.211715
# 20         6.171096
# 21         3.921162
# 22         2.254633
# 23         1.133696

# %%
counts_per_hour
# Out:
#                               counts                      date  day_name  \
# date
# 2021-12-31 23:00:00+00:00   1.687500 2021-12-31 23:00:00+00:00    Friday
# 2022-01-01 00:00:00+00:00   1.562500 2022-01-01 00:00:00+00:00  Saturday
# 2022-01-01 01:00:00+00:00   0.750000 2022-01-01 01:00:00+00:00  Saturday
# 2022-01-01 02:00:00+00:00   1.437500 2022-01-01 02:00:00+00:00  Saturday
# 2022-01-01 03:00:00+00:00   0.937500 2022-01-01 03:00:00+00:00  Saturday
# ...                              ...                       ...       ...
# 2024-03-19 18:00:00+00:00  36.517241 2024-03-19 18:00:00+00:00   Tuesday
# 2024-03-19 19:00:00+00:00  23.413793 2024-03-19 19:00:00+00:00   Tuesday
# 2024-03-19 20:00:00+00:00  12.827586 2024-03-19 20:00:00+00:00   Tuesday
# 2024-03-19 21:00:00+00:00  11.068966 2024-03-19 21:00:00+00:00   Tuesday
# 2024-03-19 22:00:00+00:00   5.137931 2024-03-19 22:00:00+00:00   Tuesday
#
#                            hours
# date
# 2021-12-31 23:00:00+00:00     23
# 2022-01-01 00:00:00+00:00      0
# 2022-01-01 01:00:00+00:00      1
# 2022-01-01 02:00:00+00:00      2
# 2022-01-01 03:00:00+00:00      3
# ...                          ...
# 2024-03-19 18:00:00+00:00     18
# 2024-03-19 19:00:00+00:00     19
# 2024-03-19 20:00:00+00:00     20
# 2024-03-19 21:00:00+00:00     21
# 2024-03-19 22:00:00+00:00     22
#
# [19416 rows x 4 columns]

# %%
plt.figure(figsize=(19, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt='d', linewidths=.5)

# Customize plot labels and title
plt.title("Comptage hoaire pour chaque jour de la semaine sur toute l'etendue des données")
plt.xlabel("heures d'une journée")
plt.ylabel("Jours de la semaine")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize=(19, 8))
# ----> 2 sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt='d', linewidths=.5)
#       4 # Customize plot labels and title
#       5 plt.title("Comptage hoaire pour chaque jour de la semaine sur toute l'etendue des données")
#
# File ~/Desktop/licence 3 rouen/S5/Data Analysis/OpenData-Rouen_Analysis_Project/env/lib/python3.9/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~/Desktop/licence 3 rouen/S5/Data Analysis/OpenData-Rouen_Analysis_Project/env/lib/python3.9/site-packages/seaborn/matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File ~/Desktop/licence 3 rouen/S5/Data Analysis/OpenData-Rouen_Analysis_Project/env/lib/python3.9/site-packages/seaborn/matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %% [markdown]
# ### Diagrammmme de chaleur de la dernier semaine

# %%
from datetime import datetime, timedelta

end_date = tidf.index[0]
start_date = end_date - timedelta(days=7)
weekly_date_range = pd.date_range(start=start_date, end=end_date, freq="H")

weekly_date_range
# Out:
# DatetimeIndex(['2024-03-01 22:00:00+00:00', '2024-03-01 23:00:00+00:00',
#                '2024-03-02 00:00:00+00:00', '2024-03-02 01:00:00+00:00',
#                '2024-03-02 02:00:00+00:00', '2024-03-02 03:00:00+00:00',
#                '2024-03-02 04:00:00+00:00', '2024-03-02 05:00:00+00:00',
#                '2024-03-02 06:00:00+00:00', '2024-03-02 07:00:00+00:00',
#                ...
#                '2024-03-08 13:00:00+00:00', '2024-03-08 14:00:00+00:00',
#                '2024-03-08 15:00:00+00:00', '2024-03-08 16:00:00+00:00',
#                '2024-03-08 17:00:00+00:00', '2024-03-08 18:00:00+00:00',
#                '2024-03-08 19:00:00+00:00', '2024-03-08 20:00:00+00:00',
#                '2024-03-08 21:00:00+00:00', '2024-03-08 22:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=169, freq='H')

# %%
df.loc[weekly_date_range]
# Out:
#                                   id  counts status  \
# 2024-03-01 23:00:00+01:00  300033014       2    raw
# 2024-03-01 23:00:00+01:00  300028856      17    raw
# 2024-03-01 23:00:00+01:00  300035391      10    raw
# 2024-03-01 23:00:00+01:00  300035455       2    raw
# 2024-03-01 23:00:00+01:00  100057696      14    raw
# ...                              ...     ...    ...
# 2024-03-08 23:00:00+01:00  100033300      11    raw
# 2024-03-08 23:00:00+01:00  300033014       2    raw
# 2024-03-08 23:00:00+01:00  300035379       2    raw
# 2024-03-08 23:00:00+01:00  300035455       5    raw
# 2024-03-08 23:00:00+01:00  100057697      10    raw
#
#                                                            name user_type  \
# 2024-03-01 23:00:00+01:00    Eco 22 - Rte de Paris FRANQUEVILLE      Vélo
# 2024-03-01 23:00:00+01:00    Eco 21 - Rue General Leclerc ROUEN      Vélo
# 2024-03-01 23:00:00+01:00         Eco 26 - Avenue Pasteur ROUEN      Vélo
# 2024-03-01 23:00:00+01:00       Eco 27 - Blvd de l'Europe ROUEN      Vélo
# 2024-03-01 23:00:00+01:00         Eco 03 - Pont Boieldieu ROUEN      Vélo
# ...                                                         ...       ...
# 2024-03-08 23:00:00+01:00  Eco 16 - Quai Pierre Corneille ROUEN      Vélo
# 2024-03-08 23:00:00+01:00    Eco 22 - Rte de Paris FRANQUEVILLE      Vélo
# 2024-03-08 23:00:00+01:00           Eco 25 - Rue d'Elbeuf ROUEN      Vélo
# 2024-03-08 23:00:00+01:00       Eco 27 - Blvd de l'Europe ROUEN      Vélo
# 2024-03-08 23:00:00+01:00    Eco 10 - Pont Guillaume Nord ROUEN      Vélo
#
#                                                                     photourl  \
# 2024-03-01 23:00:00+01:00  https://filer.eco-counter-tools.com/file/f6/3a...
# 2024-03-01 23:00:00+01:00  https://filer.eco-counter-tools.com/file/70/29...
# 2024-03-01 23:00:00+01:00  https://filer.eco-counter-tools.com/file/cf/c3...
# 2024-03-01 23:00:00+01:00  https://filer.eco-counter-tools.com/file/34/02...
# 2024-03-01 23:00:00+01:00  https://filer.eco-counter-tools.com/file/e3/47...
# ...                                                                      ...
# 2024-03-08 23:00:00+01:00  https://filer.eco-counter-tools.com/file/9d/b9...
# 2024-03-08 23:00:00+01:00  https://filer.eco-counter-tools.com/file/f6/3a...
# 2024-03-08 23:00:00+01:00  https://filer.eco-counter-tools.com/file/1b/a4...
# 2024-03-08 23:00:00+01:00  https://filer.eco-counter-tools.com/file/34/02...
# 2024-03-08 23:00:00+01:00  https://filer.eco-counter-tools.com/file/e9/1a...
#
#                                date_j
# 2024-03-01 23:00:00+01:00  2024-03-01
# 2024-03-01 23:00:00+01:00  2024-03-01
# 2024-03-01 23:00:00+01:00  2024-03-01
# 2024-03-01 23:00:00+01:00  2024-03-01
# 2024-03-01 23:00:00+01:00  2024-03-01
# ...                               ...
# 2024-03-08 23:00:00+01:00  2024-03-08
# 2024-03-08 23:00:00+01:00  2024-03-08
# 2024-03-08 23:00:00+01:00  2024-03-08
# 2024-03-08 23:00:00+01:00  2024-03-08
# 2024-03-08 23:00:00+01:00  2024-03-08
#
# [4818 rows x 7 columns]

# %%
counts_average_per_hour = tidf[["counts"]].loc[weekly_date_range].groupby([pd.Grouper(freq="h")]).mean()



counts_average_per_hour["date"] = counts_average_per_hour.index
counts_average_per_hour["day_name"] = counts_average_per_hour.date.dt.day_name()
counts_average_per_hour["hours"] = counts_average_per_hour.date.dt.hour


day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']


counts_average_per_hour['day_name'] = pd.Categorical(counts_average_per_hour['day_name'], categories=day_order, ordered=True)




heatmap_data = counts_average_per_hour.pivot_table(index='hours', columns='day_name', values='counts', aggfunc='mean', fill_value=0)


plt.figure(figsize=(19, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt=".0f", linewidths=.5)

# Customize plot labels and title
plt.title("Carte de chaleur de pour chaque jour de la semaine derniere")
plt.xlabel("Heures d'une journée")
plt.ylabel("Jours de la semaine")

# Show the plot
plt.show()

# %% [markdown]
# ### Diagramme de chaleur du dernier mois

# %%
from datetime import datetime, timedelta

end_date = tidf.index[0]
start_date = end_date - timedelta(days=365)
monthly_date_range = pd.date_range(start=start_date, end=end_date, freq="H")

start_date, end_date
# Out:
# (Timestamp('2023-02-13 22:00:00+0000', tz='UTC'),
#  Timestamp('2024-02-13 22:00:00+0000', tz='UTC'))

# %%
monthly_date_range = monthly_date_range.intersection(tidf.index)
daily_counts_average = tidf[["counts"]].loc[monthly_date_range].groupby([pd.Grouper(freq="h")]).mean()



daily_counts_average["date"] = daily_counts_average.index
daily_counts_average['month_name'] = daily_counts_average['date'].dt.strftime('%B')
daily_counts_average["hours"] = daily_counts_average.date.dt.hour


month_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 'July',
    'August', 'September', 'October', 'November', 'December'
]
daily_counts_average['month_name'] = pd.Categorical(daily_counts_average['month_name'], categories=month_order, ordered=True)




heatmap_data = daily_counts_average.pivot_table(index='hours', columns='month_name', values='counts', aggfunc='mean', fill_value=0)


plt.figure(figsize=(19, 8))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt=".0f", linewidths=.5)

# Customize plot labels and title
plt.title("Carte de chaleur de la moyenne horaire pour chaque mois de la dernier anneé")
plt.xlabel("heures d'une journée")
plt.ylabel("Jours de la semaine")

# Show the plot
plt.show()

# %% [markdown]
# ### Carte des chaleurs des moyenne par jour de la semaine, mois de l'annnée et par année

# %%
counts = tidf[["counts"]].groupby(pd.Grouper(freq="d")).mean()

counts["date"] = counts.index
counts["day_name"] = counts.date.dt.day_name()
counts
# Out:
#                               counts                      date  day_name
# date
# 2021-12-31 00:00:00+00:00   1.687500 2021-12-31 00:00:00+00:00    Friday
# 2022-01-01 00:00:00+00:00   7.557292 2022-01-01 00:00:00+00:00  Saturday
# 2022-01-02 00:00:00+00:00   6.812500 2022-01-02 00:00:00+00:00    Sunday
# 2022-01-03 00:00:00+00:00   8.458333 2022-01-03 00:00:00+00:00    Monday
# 2022-01-04 00:00:00+00:00   7.734375 2022-01-04 00:00:00+00:00   Tuesday
# ...                              ...                       ...       ...
# 2024-02-09 00:00:00+00:00  17.332340 2024-02-09 00:00:00+00:00    Friday
# 2024-02-10 00:00:00+00:00   8.328704 2024-02-10 00:00:00+00:00  Saturday
# 2024-02-11 00:00:00+00:00   7.148148 2024-02-11 00:00:00+00:00    Sunday
# 2024-02-12 00:00:00+00:00  16.952087 2024-02-12 00:00:00+00:00    Monday
# 2024-02-13 00:00:00+00:00  18.917219 2024-02-13 00:00:00+00:00   Tuesday
#
# [775 rows x 3 columns]

# %%
#counts['day_name'] = pd.Categorical(counts['day_name'], categories=day_order, ordered=True)

heatmap_data = counts.pivot_table(columns='day_name', values='counts', aggfunc='mean', fill_value=0)

heatmap_data

print("A revoir")
# Out:
# A revoir

# %% [markdown]
# ### Passages Moyens Journaliers Au Mois

# %%
counts = tidf[["counts"]].groupby(pd.Grouper(freq="h")).sum()

counts
# Out:
#                            counts
# date
# 2021-12-31 23:00:00+00:00      27
# 2022-01-01 00:00:00+00:00      25
# 2022-01-01 01:00:00+00:00      12
# 2022-01-01 02:00:00+00:00      23
# 2022-01-01 03:00:00+00:00      15
# ...                           ...
# 2024-02-13 18:00:00+00:00     876
# 2024-02-13 19:00:00+00:00     512
# 2024-02-13 20:00:00+00:00     295
# 2024-02-13 21:00:00+00:00     323
# 2024-02-13 22:00:00+00:00     134
#
# [18576 rows x 1 columns]

# %%
#counts = tidf[["counts"]].groupby(pd.Grouper(freq="24h")).sum()
counts = counts[["counts"]].groupby(pd.Grouper(freq="M")).mean()
counts
# Out:
#                                counts
# date
# 2021-12-31 00:00:00+00:00   27.000000
# 2022-01-31 00:00:00+00:00  134.795699
# 2022-02-28 00:00:00+00:00  144.037202
# 2022-03-31 00:00:00+00:00  216.862903
# 2022-04-30 00:00:00+00:00  213.934722
# 2022-05-31 00:00:00+00:00  272.883065
# 2022-06-30 00:00:00+00:00  278.290278
# 2022-07-31 00:00:00+00:00  266.266129
# 2022-08-31 00:00:00+00:00  267.502688
# 2022-09-30 00:00:00+00:00  264.806944
# 2022-10-31 00:00:00+00:00  255.126344
# 2022-11-30 00:00:00+00:00  230.598611
# 2022-12-31 00:00:00+00:00  180.134409
# 2023-01-31 00:00:00+00:00  201.489247
# 2023-02-28 00:00:00+00:00  228.785714
# 2023-03-31 00:00:00+00:00  247.975806
# 2023-04-30 00:00:00+00:00  257.372222
# 2023-05-31 00:00:00+00:00  330.090054
# 2023-06-30 00:00:00+00:00  433.440278
# 2023-07-31 00:00:00+00:00  304.977151
# 2023-08-31 00:00:00+00:00  324.048387
# 2023-09-30 00:00:00+00:00  439.677778
# 2023-10-31 00:00:00+00:00  458.668011
# 2023-11-30 00:00:00+00:00  406.912500
# 2023-12-31 00:00:00+00:00  369.901882
# 2024-01-31 00:00:00+00:00  349.487903
# 2024-02-29 00:00:00+00:00  394.823151

# %%
plt.figure(figsize=(19, 8))
sns.lineplot(data=counts, x=counts.index, y='counts', marker='o', markersize=8, label='Monthly Counts')

# Annotate each point with its value
for idx, value in enumerate(counts['counts']):
    plt.text(counts.index[idx], value, "{:.0f}".format(value),  ha='center', va='bottom', fontsize=14)

plt.show()
print("A revoir")
# Out:
# A revoir

# %% [markdown]
# ## Double indexation

# %%
didf = df.copy()
didf["date"] = didf.index
didf.set_index(["date", "id"], inplace=True)
didf
# Out:
#                                      counts status  \
# date                      id
# 2024-02-13 23:00:00+01:00 300038237       0    raw
#                           300035379       4    raw
#                           100005524       0    raw
#                           300023463       0    raw
#                           100057696       8    raw
# ...                                     ...    ...
# 2022-01-01 00:00:00+01:00 100033300       8    raw
#                           100048215       2    raw
#                           100019265       0    raw
#                           100007115       0    raw
#                           100005525       0    raw
#
#                                                                              name  \
# date                      id
# 2024-02-13 23:00:00+01:00 300038237                   Eco 28 - Pont Jaurès ELBEUF
#                           300035379                   Eco 25 - Rue d'Elbeuf ROUEN
#                           100005524        Eco 05 - Rue Boucicault MONT ST AIGNAN
#                           300023463        Eco 13 - Route de Lyons La Forêt ROUEN
#                           100057696                 Eco 03 - Pont Boieldieu ROUEN
# ...                                                                           ...
# 2022-01-01 00:00:00+01:00 100033300          Eco 16 - Quai Pierre Corneille ROUEN
#                           100048215         Eco 18 - Avenue Jacques Cartier ROUEN
#                           100019265                Eco 04 - Zénith GRAND QUEVILLY
#                           100007115   Eco 07 - Sente des Forrieres BOIS GUILLAUME
#                           100005525  Eco 06 - Rue de la Prevotiere BOIS GUILLAUME
#
#                                     user_type  \
# date                      id
# 2024-02-13 23:00:00+01:00 300038237      Vélo
#                           300035379      Vélo
#                           100005524      Vélo
#                           300023463      Vélo
#                           100057696      Vélo
# ...                                       ...
# 2022-01-01 00:00:00+01:00 100033300      Vélo
#                           100048215      Vélo
#                           100019265      Vélo
#                           100007115      Vélo
#                           100005525      Vélo
#
#                                                                               photourl  \
# date                      id
# 2024-02-13 23:00:00+01:00 300038237  https://filer.eco-counter-tools.com/file/19/15...
#                           300035379  https://filer.eco-counter-tools.com/file/1b/a4...
#                           100005524  https://filer.eco-counter-tools.com/file/88/1d...
#                           300023463  https://filer.eco-counter-tools.com/file/b8/23...
#                           100057696  https://filer.eco-counter-tools.com/file/e3/47...
# ...                                                                                ...
# 2022-01-01 00:00:00+01:00 100033300  https://filer.eco-counter-tools.com/file/9d/b9...
#                           100048215  https://filer.eco-counter-tools.com/file/b8/26...
#                           100019265  https://filer.eco-counter-tools.com/file/f1/c9...
#                           100007115  https://filer.eco-counter-tools.com/file/d4/f7...
#                           100005525  https://filer.eco-counter-tools.com/file/3f/51...
#
#                                          date_j
# date                      id
# 2024-02-13 23:00:00+01:00 300038237  2024-02-13
#                           300035379  2024-02-13
#                           100005524  2024-02-13
#                           300023463  2024-02-13
#                           100057696  2024-02-13
# ...                                         ...
# 2022-01-01 00:00:00+01:00 100033300  2022-01-01
#                           100048215  2022-01-01
#                           100019265  2022-01-01
#                           100007115  2022-01-01
#                           100005525  2022-01-01
#
# [393218 rows x 6 columns]

# %%
didf.index
# Out:
# MultiIndex([(2024-02-13 23:00:00+01:00, 300038237),
#             (2024-02-13 23:00:00+01:00, 300035379),
#             (2024-02-13 23:00:00+01:00, 100005524),
#             (2024-02-13 23:00:00+01:00, 300023463),
#             (2024-02-13 23:00:00+01:00, 100057696),
#             (2024-02-13 23:00:00+01:00, 300033014),
#             (2024-02-13 23:00:00+01:00, 300028856),
#             (2024-02-13 23:00:00+01:00, 100048215),
#             (2024-02-13 23:00:00+01:00, 100007116),
#             (2024-02-13 23:00:00+01:00, 100018293),
#             ...
#             (2022-01-01 00:00:00+01:00, 100007117),
#             (2022-01-01 00:00:00+01:00, 100018294),
#             (2022-01-01 00:00:00+01:00, 100057697),
#             (2022-01-01 00:00:00+01:00, 100033301),
#             (2022-01-01 00:00:00+01:00, 100018293),
#             (2022-01-01 00:00:00+01:00, 100033300),
#             (2022-01-01 00:00:00+01:00, 100048215),
#             (2022-01-01 00:00:00+01:00, 100019265),
#             (2022-01-01 00:00:00+01:00, 100007115),
#             (2022-01-01 00:00:00+01:00, 100005525)],
#            names=['date', 'id'], length=393218)
